# %% [markdown]
# # Triage Troopers Code

# %%
# mount drive for access
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import Libraries
import pandas as pd
import numpy as np
import re

# %%
# Open dataset
df = pd.read_csv("/content/drive/Shareddrives/BE 5740 - Final Project/Triage Dataset - Original.xlsx - N=1267 data.csv",sep=',')
df.head()
# Out:
#    Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 0      2    2   71                         3             3       2
# 1      1    1   56                        12             3       2
# 2      2    1   68                         8             2       2
# 3      1    2   71                         8             1       1
# 4      1    2   58                         4             3       1
#
#        Chief_complain  Mental  Pain NRS_pain  ...    BT Saturation KTAS_RN  \
# 0   right ocular pain       1     1        2  ...  36.6        100       2
# 1  right forearm burn       1     1        2  ...  36.5        NaN       4
# 2        arm pain, Lt       1     1        2  ...  36.6         98       4
# 3     ascites tapping       1     1        3  ...  36.5        NaN       4
# 4     distension, abd       1     1        3  ...  36.5        NaN       4
#
#                                 Diagnosis in ED Disposition KTAS_expert  \
# 0                              Corneal abrasion           1           4
# 1             Burn of hand, firts degree dorsum           1           5
# 2  Fracture of surgical neck of humerus, closed           2           5
# 3        Alcoholic liver cirrhosis with ascites           1           5
# 4                                       Ascites           1           5
#
#    Error_group Length of stay_min  KTAS duration_min  mistriage
# 0            2                 86               5.00          1
# 1            4                 64               3.95          1
# 2            4                862               1.00          1
# 3            6                108               9.83          1
# 4            8                109               6.60          1
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (1267, 24)

# %% [markdown]
# # Data Preprocessing

# %%
# Analyze the missing values in a DataFrame and provides a summary table and output a list

def missing_values_table(dataframe):
    # Replace '#NULL!' with NaN
    dataframe.replace("#NULL!", np.nan, inplace=True)

    variables_with_na = [col for col in dataframe.columns if dataframe[col].isnull().sum() > 0]
    n_miss = dataframe[variables_with_na].isnull().sum().sort_values(ascending=False)
    ratio = (dataframe[variables_with_na].isnull().sum() / dataframe.shape[0] * 100).sort_values(ascending=False)
    missing_df = pd.concat([n_miss, np.round(ratio, 2)], axis=1, keys=['n_miss', 'ratio'])
    print(missing_df)
    return variables_with_na

#usage:
missing_values_table(df)
# Out:
#                  n_miss  ratio
# Saturation          688  54.30
# NRS_pain            556  43.88
# Diagnosis in ED       2   0.16
# ['NRS_pain', 'Saturation', 'Diagnosis in ED']

# %%
## Fill in missing values in the NRS_pain, Saturation, and Diagnosis in ED columns of a DataFrame (df)
## based on the mode (most frequent value) within groups defined by two other columns (mistriage and KTAS_expert)
## ensures that the filled values are representative of each subgroup rather than just using the overall mode of the entire column

df["NRS_pain"] = df.groupby(["mistriage", "KTAS_expert"])["NRS_pain"].transform(lambda x: x.fillna(x.mode()[0]))
df["Saturation"] = df.groupby(["mistriage", "KTAS_expert"])["Saturation"].transform(lambda x: x.fillna(x.mode()[0]))
df["Diagnosis in ED"] = df.groupby(["mistriage", "KTAS_expert"])["Diagnosis in ED"].transform(lambda x: x.fillna(x.mode()[0]))

df
# Out:
#       Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 0         2    2   71                         3             3       2
# 1         1    1   56                        12             3       2
# 2         2    1   68                         8             2       2
# 3         1    2   71                         8             1       1
# 4         1    2   58                         4             3       1
# ...     ...  ...  ...                       ...           ...     ...
# 1262      2    2   79                         5             2       1
# 1263      2    2   81                         2             3       1
# 1264      2    2   81                        17             2       1
# 1265      2    1   81                         2             2       2
# 1266      2    2   87                         8             4       1
#
#           Chief_complain  Mental  Pain NRS_pain  ...    BT Saturation KTAS_RN  \
# 0      right ocular pain       1     1        2  ...  36.6        100       2
# 1     right forearm burn       1     1        2  ...  36.5         98       4
# 2           arm pain, Lt       1     1        2  ...  36.6         98       4
# 3        ascites tapping       1     1        3  ...  36.5         98       4
# 4        distension, abd       1     1        3  ...  36.5         98       4
# ...                  ...     ...   ...      ...  ...   ...        ...     ...
# 1262       mental change       1     0        3  ...  36.4         95       2
# 1263             dysuria       1     0        3  ...  36.4         97       4
# 1264           dizziness       1     0        5  ...  36.2         99       3
# 1265  Sensory, Decreased       1     0        5  ...  36.6         98       3
# 1266           orthopnea       1     0        5  ...  36.2         98       3
#
#                                         Diagnosis in ED Disposition  \
# 0                                      Corneal abrasion           1
# 1                     Burn of hand, firts degree dorsum           1
# 2          Fracture of surgical neck of humerus, closed           2
# 3                Alcoholic liver cirrhosis with ascites           1
# 4                                               Ascites           1
# ...                                                 ...         ...
# 1262  Cerebral infarction due to unspecified occlusi...           2
# 1263                                            Dysuria           1
# 1264                            Dizziness and giddiness           1
# 1265                      Cord compression, unspecified           7
# 1266                                           Dyspnoea           2
#
#      KTAS_expert  Error_group Length of stay_min  KTAS duration_min  mistriage
# 0              4            2                 86               5.00          1
# 1              5            4                 64               3.95          1
# 2              5            4                862               1.00          1
# 3              5            6                108               9.83          1
# 4              5            8                109               6.60          1
# ...          ...          ...                ...                ...        ...
# 1262           2            0               1995               3.00          0
# 1263           4            0               1000               2.00          0
# 1264           3            0                310               4.00          0
# 1265           3            0                475               5.00          0
# 1266           3            0                887               2.00          0
#
# [1267 rows x 24 columns]

# %%
# Removing rows with Korean characters

def has_korean(text):
    # Regular expression to detect Korean characters
    korean_pattern = re.compile("[\u3131-\uD79D]+")
    return bool(korean_pattern.search(text))

def missing_values_table(dataframe):
    variables_with_na = [col for col in dataframe.columns if dataframe[col].isnull().sum() > 0]
    n_miss = dataframe[variables_with_na].isnull().sum().sort_values(ascending=False)
    ratio = (dataframe[variables_with_na].isnull().sum() / dataframe.shape[0] * 100).sort_values(ascending=False)
    missing_df = pd.concat([n_miss, np.round(ratio, 2)], axis=1, keys=['n_miss', 'ratio'])

    # Filtering rows with Korean text in any column
    rows_with_korean = dataframe[dataframe.apply(lambda row: any(has_korean(str(cell)) for cell in row), axis=1)]
    cleaned_dataframe = dataframe.drop(rows_with_korean.index)

    print("Rows with Korean text:")
    print(rows_with_korean)

    print("\nCleaned DataFrame:")
    print(cleaned_dataframe)
    print("\nCleaned DataFrame Shape:", cleaned_dataframe.shape)

    print("\nNumber of rows removed due to Korean text:", len(rows_with_korean))

    print("\nMissing Values Summary:", missing_df.shape)
    print(missing_df)

    return cleaned_dataframe, variables_with_na  # Return the cleaned DataFrame along with variables_with_na

# usage:
df['NRS_pain'] = df['NRS_pain'].replace("#BO�!", np.NaN)
df_english, variables_with_na = missing_values_table(df)

print("\nVariables with Missing Values:", variables_with_na)
# Out:
# Rows with Korean text:
#       Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 16        1    2   69                        11             2       1
# 34        1    1   19                        11             2       1
# 38        1    2   47                        10             2       2
# 61        2    1   70                         8             2       1
# 65        1    1   70                        10             3       1
# 121       1    2   48                         5             2       1
# 122       1    1   50                         9             3       1
# 123       1    1   50                         9             3       1
# 150       1    2   77                         4             3       1
# 153       2    2   65                         7             2       2
# 155       1    1   78                         6             2       1
# 161       1    1   77                         5             4       1
# 164       2    1   80                         7             4       1
# 180       2    2   43                        17             3       1
# 189       1    1   79                        15             3       2
# 190       1    1   78                         6             2       1
# 215       2    2   79                         5             2       2
# 226       1    2   49                        12             3       1
# 227       1    1   59                         7             2       1
# 277       1    2   30                        10             3       1
# 310       2    2   40                         3             3       1
# 354       1    2   56                        10             2       1
# 378       1    1   61                         5             3       1
# 388       1    1   66                         6             3       1
# 400       1    2   71                        11             3       1
# 427       1    2   78                         8             2       1
# 541       1    1   73                         9             1       1
# 677       2    1   29                         8             3       2
# 704       2    2   60                         3             3       1
# 705       2    2   61                         8             4       2
# 787       1    1   81                        11             4       1
# 793       1    2   62                         3             3       1
# 804       1    1   79                         9             2       1
# 820       1    2   76                         3             3       1
# 822       1    1   80                         7             2       1
# 836       1    2   20                         8             3       1
# 844       1    1   22                        13             3       1
# 887       1    2   33                         8             3       1
# 904       1    2   36                         9             3       1
# 906       2    1   37                         8             3       1
# 925       1    1   42                         4             2       1
# 927       1    2   43                        11             3       1
# 933       1    2   44                         4             3       1
# 961       1    1   50                         7             3       1
# 967       1    2   51                        13             3       1
# 968       2    1   51                         1             4       1
# 971       2    1   52                        11             4       1
# 1006      2    1   58                         1             4       2
# 1009      2    2   58                        15             4       1
# 1020      1    2   59                         9             3       2
# 1039      1    1   63                         7             2       1
# 1054      2    2   65                        12             2       1
# 1073      2    1   68                         8             4       1
# 1078      1    2   68                         7             2       1
# 1132      1    2   75                         5             2       2
# 1134      1    1   75                         5             2       2
# 1143      2    1   76                         9             4       1
# 1171      1    2   80                         9             2       1
# 1185      1    1   82                         8             3       1
# 1245      2    2   66                        17             4       2
#
#               Chief_complain  Mental  Pain NRS_pain  ...    BT Saturation  \
# 16                        설사       1     1        4  ...  37.4         98
# 34                        구토       1     0        3  ...  36.9         98
# 38                        열상       1     0        3  ...  36.6         98
# 61                   dyspnea       2     1        3  ...  36.3         78
# 65                     목이 아픔       1     1        3  ...  36.8         97
# 121                  dyspnea       1     0        3  ...    측불         68
# 122      Blood Pressure, Low       3     0        3  ...    측불         68
# 123      Blood Pressure, Low       3     0        3  ...    측불         68
# 150            mental change       3     0        3  ...    측불         68
# 153            mental change       3     0        3  ...  36.0         94
# 155           Motor weakness       4     0        3  ...    측불         68
# 161                   melena       3     0        3  ...  37.4         68
# 164                  dyspnea       3     0        3  ...  36.6         측불
# 180         erection, penile       1     0        3  ...    측불         측불
# 189                턱이 빠진것 같다       1     1        2  ...  36.3         98
# 190                       흉통       1     1        2  ...  35.9         98
# 215            mental change       4     1        2  ...  36.4         99
# 226                    명치 아픔       1     1        3  ...    36         98
# 227                   변비가 있다       2     1        3  ...    36         98
# 277                   속이 거북함       1     1        3  ...  36.9         98
# 310            Leg pain, NOS       1     1        3  ...  36.4         측불
# 354            both leg pain       2     1        3  ...    측불         98
# 378                     피부병변       1     1        3  ...    37         98
# 388                      상복부       1     1        3  ...  37.5         98
# 400                소변이 잘 안나옴       1     1        3  ...  36.8         98
# 427            alcohol smell       1     1        3  ...    측불         98
# 541                     피부병변       1     1        4  ...  36.3         98
# 677   foreign body ingestion       1     1        6  ...  36.5         측불
# 704                  dysuria       1     1        6  ...  36.6         측불
# 705                 abd pain       1     1        6  ...    측불         측불
# 787       sezure like motion       1     0        5  ...    37         98
# 793                   소변이 적다       1     0        3  ...  36.5         98
# 804            mental change       4     0        2  ...    36         측불
# 820            mental change       4     0        2  ...    측불         측불
# 822                  dyspnea       1     0        3  ...  36.8         98
# 836               이상한 행동을 한다       1     0        3  ...    36         98
# 844                     심계항진       1     0        3  ...  36.6         98
# 887                  seizure       4     0        2  ...    측불         측불
# 904                     어지러움       1     0        5  ...    36         98
# 906                 headache       1     0        3  ...  36.3         측불
# 925       left side weakness       1     0        3  ...    37         98
# 927                       구토       1     0        3  ...  36.8         98
# 933                   손발이 저림       1     0        5  ...  36.2         98
# 961                      우울증       1     0        5  ...    37         98
# 967             CT film copy       1     0        3  ...    측불         98
# 968            mental change       4     0        2  ...  35.7         86
# 971                    fever       1     0        3  ...  38.5         97
# 1006          post-CPR state       4     0        2  ...  36.0         90
# 1009          post-CPR state       4     0        2  ...    측불         측불
# 1020                    copy       1     0        3  ...    측불         98
# 1039                  arrest       4     0        2  ...    측불         측불
# 1054   loss of consciousness       1     0        3  ...  36.3         91
# 1073           mental change       4     0        2  ...  35.8         95
# 1078   altered mental change       4     0        2  ...  37.3         측불
# 1132           mental change       4     0        2  ...    36         측불
# 1134       altered mentality       3     0        3  ...    측불         98
# 1143          post-CPR state       4     0        2  ...    측불         측불
# 1171           acute dyspnea       3     0        2  ...    측불         측불
# 1185                  다리 차가움       1     0        3  ...    36         98
# 1245         ant. chest pain       1     1        6  ...  36.2         96
#
#      KTAS_RN                                    Diagnosis in ED Disposition  \
# 16         3                              Acute gastroenteritis           1
# 34         2                                    Acute gastritis           1
# 38         3                          Laceration of oral cavity           1
# 61         2                                           Dyspnoea           6
# 65         5                                   Hyperventilation           1
# 121        2                                            Dyspnea           1
# 122        2                                            Colitis           3
# 123        2                                        Hypotension           3
# 150        2               End stage kidney disease on dialysis           2
# 153        2  Traumatic subdural hemorrhage without open int...           5
# 155        2                                         Dysarthria           2
# 161        2                                       Hematochezia           3
# 164        2                                           Dyspnoea           5
# 180        5                                           Priapism           1
# 189        5                                 Dislocation of jaw           1
# 190        2                                         Chest pain           1
# 215        1  Traumatic subdural hemorrhage without open int...           2
# 226        4                                    Epigastric pain           1
# 227        4                                       Constipation           1
# 277        4                                             Nausea           1
# 310        5             Complex regional pain syndrome type II           1
# 354        5                                          Knee pain           1
# 378        5                                               Rash           2
# 388        4                              Acute gastroenteritis           1
# 400        4      Benign prostatic hyperplasia with obstruction           1
# 427        4                      Acute intoxication of alcohol           1
# 541        4                                      Herpes zoster           1
# 677        3                                Chronic sore throat           1
# 704        4                      Urinary tract obstruction NOS           1
# 705        1                          Contusion of abdomen wall           6
# 787        3                                            Seizure           1
# 793        4                       Benign prostatic hyperplasia           1
# 804        1  Ruptured aneurysm, anterior communicating arte...           2
# 820        1                                     Cardiac arrest           5
# 822        2                                            Dyspnea           2
# 836        4                                      Schizophrenia           2
# 844        4                                        Palpitation           1
# 887        1                                            Seizure           4
# 904        3                                          Dizziness           1
# 906        4                                           Headache           1
# 925        2                              Muscle weakness other           2
# 927        4                                       Ureter stone           1
# 933        3                                        Paresthesia           2
# 961        3                                         Depression           2
# 967        5                           Hepatocellular carcinoma           1
# 968        1       Cardiac arrest with successful resuscitation           6
# 971        2                               Acute pyelonephritis           2
# 1006       1       Cardiac arrest with successful resuscitation           2
# 1009       1                        Cardiac arrest, unspecified           6
# 1020       5                                             Stroke           1
# 1039       1                                     Cardiac arrest           6
# 1054       2                                    Anaphylaxis NOS           1
# 1073       1       Cardiac arrest with successful resuscitation           2
# 1078       1                           Intracerebral hemorrhage           3
# 1132       1                                    Multiple trauma           6
# 1134       2  Subarachnoid hemorrhage, traumatic without ope...           2
# 1143       1                        Cardiac arrest, unspecified           6
# 1171       1  Acute exacerbation of idiopathic pulmonary fib...           2
# 1185       2                   Atherosclerosis obliterans, limb           2
# 1245       2                          Contusion of abdomen wall           7
#
#      KTAS_expert  Error_group Length of stay_min  KTAS duration_min  mistriage
# 16             4            1                363              10.53          1
# 34             4            2                108              14.60          1
# 38             4            2                576              13.43          1
# 61             1            1                593               2.00          2
# 65             4            4                161               4.97          2
# 121            1            1                272               4.10          2
# 122            1            1                496               6.40          2
# 123            1            1                496               6.40          2
# 150            1            4                323              13.90          2
# 153            1            5                150               2.00          2
# 155            1            5                234               9.35          2
# 161            1            7                351               4.42          2
# 164            1            7              20098               3.00          2
# 180            2            2                594               5.00          2
# 189            5            0                 12               2.78          0
# 190            2            0                222               6.48          0
# 215            1            0                101               5.00          0
# 226            4            0                123              10.05          0
# 227            4            0                340               3.40          0
# 277            4            0                 61               4.55          0
# 310            5            0                 60               2.00          0
# 354            5            0                545               3.87          0
# 378            5            0                291               6.92          0
# 388            4            0                155               8.38          0
# 400            4            0                158               3.73          0
# 427            4            0                393               7.05          0
# 541            4            0                 35               7.70          0
# 677            3            0                122               5.00          0
# 704            4            0                 55               2.00          0
# 705            1            0                275               5.00          0
# 787            3            0                982               8.98          0
# 793            4            0                 26               4.02          0
# 804            1            0                431              10.83          0
# 820            1            0                150               8.90          0
# 822            2            0                324               2.33          0
# 836            4            0                213              11.28          0
# 844            4            0                163               5.07          0
# 887            1            0                 56               7.42          0
# 904            3            0                277               4.67          0
# 906            4            0                210               4.00          0
# 925            2            0                264               6.53          0
# 927            4            0                118              15.57          0
# 933            3            0                249               6.23          0
# 961            3            0                172              13.68          0
# 967            5            0                 32               6.38          0
# 968            1            0                392               5.00          0
# 971            2            0               9710               4.00          0
# 1006           1            0               1010               2.00          0
# 1009           1            0                123               2.00          0
# 1020           5            0                 21               6.88          0
# 1039           1            0                 72               5.42          0
# 1054           2            0                407               1.00          0
# 1073           1            0                408               4.00          0
# 1078           1            0                135               5.62          0
# 1132           1            0                311               6.62          0
# 1134           2            0                504               6.32          0
# 1143           1            0                 35               4.00          0
# 1171           1            0                257               3.92          0
# 1185           2            0                242               9.27          0
# 1245           2            0                 36               3.00          0
#
# [60 rows x 24 columns]
#
# Cleaned DataFrame:
#       Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 0         2    2   71                         3             3       2
# 1         1    1   56                        12             3       2
# 2         2    1   68                         8             2       2
# 3         1    2   71                         8             1       1
# 4         1    2   58                         4             3       1
# ...     ...  ...  ...                       ...           ...     ...
# 1262      2    2   79                         5             2       1
# 1263      2    2   81                         2             3       1
# 1264      2    2   81                        17             2       1
# 1265      2    1   81                         2             2       2
# 1266      2    2   87                         8             4       1
#
#           Chief_complain  Mental  Pain NRS_pain  ...    BT Saturation KTAS_RN  \
# 0      right ocular pain       1     1        2  ...  36.6        100       2
# 1     right forearm burn       1     1        2  ...  36.5         98       4
# 2           arm pain, Lt       1     1        2  ...  36.6         98       4
# 3        ascites tapping       1     1        3  ...  36.5         98       4
# 4        distension, abd       1     1        3  ...  36.5         98       4
# ...                  ...     ...   ...      ...  ...   ...        ...     ...
# 1262       mental change       1     0        3  ...  36.4         95       2
# 1263             dysuria       1     0        3  ...  36.4         97       4
# 1264           dizziness       1     0        5  ...  36.2         99       3
# 1265  Sensory, Decreased       1     0        5  ...  36.6         98       3
# 1266           orthopnea       1     0        5  ...  36.2         98       3
#
#                                         Diagnosis in ED Disposition  \
# 0                                      Corneal abrasion           1
# 1                     Burn of hand, firts degree dorsum           1
# 2          Fracture of surgical neck of humerus, closed           2
# 3                Alcoholic liver cirrhosis with ascites           1
# 4                                               Ascites           1
# ...                                                 ...         ...
# 1262  Cerebral infarction due to unspecified occlusi...           2
# 1263                                            Dysuria           1
# 1264                            Dizziness and giddiness           1
# 1265                      Cord compression, unspecified           7
# 1266                                           Dyspnoea           2
#
#      KTAS_expert  Error_group Length of stay_min  KTAS duration_min  mistriage
# 0              4            2                 86               5.00          1
# 1              5            4                 64               3.95          1
# 2              5            4                862               1.00          1
# 3              5            6                108               9.83          1
# 4              5            8                109               6.60          1
# ...          ...          ...                ...                ...        ...
# 1262           2            0               1995               3.00          0
# 1263           4            0               1000               2.00          0
# 1264           3            0                310               4.00          0
# 1265           3            0                475               5.00          0
# 1266           3            0                887               2.00          0
#
# [1207 rows x 24 columns]
#
# Cleaned DataFrame Shape: (1207, 24)
#
# Number of rows removed due to Korean text: 60
#
# Missing Values Summary: (0, 2)
# Empty DataFrame
# Columns: [n_miss, ratio]
# Index: []
#
# Variables with Missing Values: []

# %%
df_english
# Out:
#       Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 0         2    2   71                         3             3       2
# 1         1    1   56                        12             3       2
# 2         2    1   68                         8             2       2
# 3         1    2   71                         8             1       1
# 4         1    2   58                         4             3       1
# ...     ...  ...  ...                       ...           ...     ...
# 1262      2    2   79                         5             2       1
# 1263      2    2   81                         2             3       1
# 1264      2    2   81                        17             2       1
# 1265      2    1   81                         2             2       2
# 1266      2    2   87                         8             4       1
#
#           Chief_complain  Mental  Pain NRS_pain  ...    BT Saturation KTAS_RN  \
# 0      right ocular pain       1     1        2  ...  36.6        100       2
# 1     right forearm burn       1     1        2  ...  36.5         98       4
# 2           arm pain, Lt       1     1        2  ...  36.6         98       4
# 3        ascites tapping       1     1        3  ...  36.5         98       4
# 4        distension, abd       1     1        3  ...  36.5         98       4
# ...                  ...     ...   ...      ...  ...   ...        ...     ...
# 1262       mental change       1     0        3  ...  36.4         95       2
# 1263             dysuria       1     0        3  ...  36.4         97       4
# 1264           dizziness       1     0        5  ...  36.2         99       3
# 1265  Sensory, Decreased       1     0        5  ...  36.6         98       3
# 1266           orthopnea       1     0        5  ...  36.2         98       3
#
#                                         Diagnosis in ED Disposition  \
# 0                                      Corneal abrasion           1
# 1                     Burn of hand, firts degree dorsum           1
# 2          Fracture of surgical neck of humerus, closed           2
# 3                Alcoholic liver cirrhosis with ascites           1
# 4                                               Ascites           1
# ...                                                 ...         ...
# 1262  Cerebral infarction due to unspecified occlusi...           2
# 1263                                            Dysuria           1
# 1264                            Dizziness and giddiness           1
# 1265                      Cord compression, unspecified           7
# 1266                                           Dyspnoea           2
#
#      KTAS_expert  Error_group Length of stay_min  KTAS duration_min  mistriage
# 0              4            2                 86               5.00          1
# 1              5            4                 64               3.95          1
# 2              5            4                862               1.00          1
# 3              5            6                108               9.83          1
# 4              5            8                109               6.60          1
# ...          ...          ...                ...                ...        ...
# 1262           2            0               1995               3.00          0
# 1263           4            0               1000               2.00          0
# 1264           3            0                310               4.00          0
# 1265           3            0                475               5.00          0
# 1266           3            0                887               2.00          0
#
# [1207 rows x 24 columns]

# %% [markdown]
# # Mistriage Counts

# %%
# Open dataset
df_bar_chart = pd.read_csv("/content/drive/Shareddrives/BE 5740 - Final Project/Dataset Summary Code/Remaining_Values_Diagnoses.csv",sep=',')
df_bar_chart.head()
df_bar_chart
# Out:
#       Group  Sex  Age  Patients number per hour  Arrival mode  Injury  \
# 0         1    2   18                        12             1       1
# 1         1    1   29                         3             2       1
# 2         1    2   55                         3             3       1
# 3         1    1   74                         7             3       1
# 4         1    1   36                         4             4       1
# ...     ...  ...  ...                       ...           ...     ...
# 1226      1    1   50                         7             3       1
# 1227      1    2   20                         8             3       1
# 1228      1    1   79                        15             3       2
# 1229      1    1   73                         9             1       1
# 1230      1    1   61                         5             3       1
#
#                      Chief_complain  Mental  Pain  SBP  ...    BT  \
# 0                          abd pain       1     1  107  ...  38.4
# 1                          abd pain       1     1  140  ...  36.0
# 2                          abd pain       1     1  152  ...  37.0
# 3                          abd pain       1     1  118  ...  36.9
# 4                          abd pain       1     0  126  ...  38.0
# ...                             ...     ...   ...  ...  ...   ...
# 1226               우울증 (depression)       1     0  140  ...  37.0
# 1227  이상한 행동을 한다 (acting strangely)       1     0  163  ...  36.0
# 1228      턱이 빠진것 같다 ("missing" jaw)       1     1  137  ...  36.3
# 1229             피부병변 (skin lesion)       1     1  148  ...  36.3
# 1230             피부병변 (skin lesion)       1     1   90  ...  37.0
#
#       Diagnoses Values        Diagnosis in ED  Disposition  KTAS_RN  \
# 0                    2         Abdominal pain            1        3
# 1                    7           Dysmenorrhea            4        3
# 2                    2  Acute gastroenteritis            1        4
# 3                    4           Parkinsonism            1        3
# 4                    2         Abdominal pain            2        3
# ...                ...                    ...          ...      ...
# 1226                 9             Depression            2        3
# 1227                 9          Schizophrenia            2        4
# 1228                 6     Dislocation of jaw            1        5
# 1229                 5          Herpes zoster            1        4
# 1230                10                   Rash            2        5
#
#      KTAS_expert  mistriage  Error_group  Length of stay_min  \
# 0              3          0            0                   0
# 1              3          0            0                  34
# 2              4          0            0                  50
# 3              3          0            0                  56
# 4              3          0            0                  62
# ...          ...        ...          ...                 ...
# 1226           3          0            0                 172
# 1227           4          0            0                 213
# 1228           5          0            0                  12
# 1229           4          0            0                  35
# 1230           5          0            0                 291
#
#       KTAS duration_min
# 0                  6.00
# 1                  4.12
# 2                  9.65
# 3                  8.72
# 4                  5.70
# ...                 ...
# 1226              13.68
# 1227              11.28
# 1228               2.78
# 1229               7.70
# 1230               6.92
#
# [1231 rows x 23 columns]

# %%
#
# Correct,3,176,399,418,60
# Over triage,0,3,16,24,12
# Under triage,2,33,71,15,0

import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['1', '2', '3', '4', '5']
correct = [3, 176, 399, 418, 60]
over_triage = [0, 3, 16, 24, 12]
under_triage = [2, 33, 71, 15, 0]

# Define the width of the bars
bar_width = 0.25

# Set the positions of the bars on the x-axis
r1 = np.arange(len(correct))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Create the bars
plt.bar(r1, correct, color='teal', width=bar_width, edgecolor='grey', label='Correct')
plt.bar(r2, over_triage, color='darkviolet', width=bar_width, edgecolor='grey', label='Over Triage')
plt.bar(r3, under_triage, color='dodgerblue', width=bar_width, edgecolor='grey', label='Under Triage')

# Add labels, title, and legend
plt.xlabel('Urgency of Diagnoses (KTAS scores of experts)', fontweight='bold')
plt.ylabel('Count', fontweight='bold')
plt.xticks([r + bar_width for r in range(len(correct))], categories)
plt.title('Triage Counts by Urgency of Diagnoses (KTAS scores of experts)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Models

# %% [markdown]
# # SVM - Vitals Taken (All Features)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Data preprocessing (double check)
df_english.dropna(inplace=True)

# Selecting only the desired features
selected_features = ['Group', 'Age', 'Patients number per hour', 'Sex', 'Arrival mode', 'Injury', 'Chief_complain', 'Mental', 'Pain', 'NRS_pain',
                     'SBP', 'DBP', 'HR', 'RR', 'BT', 'Saturation', 'Length of stay_min', 'Disposition']
X = df_english[selected_features]
y = df_english['mistriage']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Normalize/Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print("Features used in the model:", X_encoded.columns)


# Model training with probability estimates
svm_model = SVC(kernel='linear', probability=True)

# Perform k-fold cross-validation
cv_scores = cross_val_score(svm_model, X_train, y_train, cv=5)

# Binarize the output for all features
y_test_bin_all = label_binarize(y_test, classes=[0, 1, 2])

print("Cross-validation scores:", cv_scores)
print("Average cross-validation score:", round(cv_scores.mean() * 100, 2), "%")
# Out:
# Features used in the model: Index(['Group', 'Age', 'Patients number per hour', 'Sex', 'Arrival mode',
#        'Injury', 'Mental', 'Pain', 'Length of stay_min', 'Disposition',
#        ...
#        'Saturation_90', 'Saturation_91', 'Saturation_92', 'Saturation_93',
#        'Saturation_94', 'Saturation_95', 'Saturation_96', 'Saturation_97',
#        'Saturation_98', 'Saturation_99'],
#       dtype='object', length=785)
# Cross-validation scores: [0.77720207 0.77720207 0.76165803 0.79274611 0.75129534]
# Average cross-validation score: 77.2 %

# %%
# Model evaluation
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)
y_probs_all_features = svm_model.predict_proba(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", round(accuracy * 100, 2), "%")

report = classification_report(y_test, y_pred, output_dict=True)
precision = report['macro avg']['precision']
f1_score = report['macro avg']['f1-score']
sensitivity = report['macro avg']['recall']
specificity = report['weighted avg']['recall']

print("Precision:", round(precision * 100, 2), "%")
print("F1 Score:", round(f1_score * 100, 2), "%")
print("Sensitivity:", round(sensitivity * 100, 2), "%")
print("Specificity:", round(specificity * 100, 2), "%")


# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 77.69 %
# Precision: 38.26 %
# F1 Score: 37.95 %
# Sensitivity: 37.65 %
# Specificity: 77.69 %
# Confusion Matrix:
# [[181   9  18]
#  [  6   0   1]
#  [ 19   1   7]]

# %% [markdown]
# # SVM - No Vitals Taken (Selected Columns)

# %%
# Data preprocessing
# Drop rows with missing values
df_english.dropna(inplace=True)

# Specify columns for model training
selected_columns = ['Group', 'Age', 'Patients number per hour','Sex', 'Arrival mode', 'Injury', 'Chief_complain', 'Mental', 'Pain', 'Length of stay_min', 'Disposition', 'NRS_pain']


# Separate features and target variable
X = df_english[selected_columns]
y = df_english['mistriage']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Normalize/Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model training with probability estimates
svm_model = SVC(kernel='linear', probability=True)

# Perform k-fold cross-validation
cv_scores = cross_val_score(svm_model, X_train, y_train, cv=5)

# Binarize the output for all features
y_test_bin_selected = label_binarize(y_test, classes=[0, 1, 2])


print("Cross-validation scores:", cv_scores)
print("Average cross-validation score:", round(cv_scores.mean() * 100, 2), "%")
# Out:
# Cross-validation scores: [0.86528497 0.86528497 0.85492228 0.83419689 0.79792746]
# Average cross-validation score: 84.35 %

# %%
# Model evaluation
svm_model.fit(X_train, y_train)  # Train on the entire training set
y_pred = svm_model.predict(X_test)
y_probs_selected_features = svm_model.predict_proba(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", round(accuracy * 100, 2), "%")

report = classification_report(y_test, y_pred, output_dict=True)
precision = report['macro avg']['precision']
f1_score = report['macro avg']['f1-score']
sensitivity = report['macro avg']['recall']
specificity = report['weighted avg']['recall']

print("Precision:", round(precision * 100, 2), "%")
print("F1 Score:", round(f1_score * 100, 2), "%")
print("Sensitivity:", round(sensitivity * 100, 2), "%")
print("Specificity:", round(specificity * 100, 2), "%")

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 87.6 %
# Precision: 51.24 %
# F1 Score: 45.75 %
# Sensitivity: 43.64 %
# Specificity: 87.6 %
# Confusion Matrix:
# [[203   1   4]
#  [  6   0   1]
#  [ 18   0   9]]

# %% [markdown]
# # ROC Curves for SVM Models

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Plot ROC curve for all features
fpr_all, tpr_all, _ = roc_curve(y_test_bin_all[:, 0], y_probs_all_features[:, 0])
roc_auc_all = roc_auc_score(y_test_bin_all[:, 0], y_probs_all_features[:, 0])
plt.plot(fpr_all, tpr_all, color='blue', lw=2, label=f'All Features (AUC = {roc_auc_all:0.2f})')

# Plot ROC curve for selected features
fpr_sel, tpr_sel, _ = roc_curve(y_test_bin_selected[:, 0], y_probs_selected_features[:, 0])
roc_auc_sel = roc_auc_score(y_test_bin_selected[:, 0], y_probs_selected_features[:, 0])
plt.plot(fpr_sel, tpr_sel, color='red', lw=2, label=f'Selected Features (AUC = {roc_auc_sel:0.2f})')

# Plot the diagonal line (random classifier)
plt.plot([0, 1], [0, 1], 'k--', lw=2)

# Set labels and title
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison \n Between Vitals and No Vitals SVM Models')
plt.legend(loc='lower right')
plt.grid(False)

# Show plot
plt.show()

# %% [markdown]
# # Random Forest - Vitals Taken (All Features)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score
import matplotlib.pyplot as plt


# Data preprocessing (double check)
df_english.dropna(inplace=True)

# Selecting only the desired features
selected_features = ['Group', 'Age', 'Patients number per hour', 'Sex', 'Arrival mode', 'Injury', 'Chief_complain', 'Mental', 'Pain', 'NRS_pain',
                     'SBP', 'DBP', 'HR', 'RR', 'BT', 'Saturation', 'Length of stay_min', 'Disposition']
X = df_english[selected_features]
y = df_english['mistriage']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Normalize/Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model training with probability estimates
rf_model_all = RandomForestClassifier(n_estimators=100, random_state=42)

# Perform k-fold cross-validation
cv_scores = cross_val_score(rf_model_all, X_train, y_train, cv=5)

# Binarize the output for all features
y_test_bin_all = label_binarize(y_test, classes=[0, 1, 2])

print("Cross-validation scores:", cv_scores)
print("Average cross-validation score:", round(cv_scores.mean() * 100, 2), "%")
# Out:
# Cross-validation scores: [0.86010363 0.86010363 0.85492228 0.85492228 0.85492228]
# Average cross-validation score: 85.7 %

# %%
# Model evaluation
rf_model_all.fit(X_train, y_train)
y_pred = rf_model_all.predict(X_test)
y_probs_all_features = rf_model_all.predict_proba(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", round(accuracy * 100, 2), "%")

report = classification_report(y_test, y_pred, output_dict=True)
precision = report['macro avg']['precision']
f1_score = report['macro avg']['f1-score']
sensitivity = report['macro avg']['recall']
specificity = report['weighted avg']['recall']

print("Precision:", round(precision * 100, 2), "%")
print("F1 Score:", round(f1_score * 100, 2), "%")
print("Sensitivity:", round(sensitivity * 100, 2), "%")
print("Specificity:", round(specificity * 100, 2), "%")


# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 85.95 %
# Precision: 28.65 %
# F1 Score: 30.81 %
# Sensitivity: 33.33 %
# Specificity: 85.95 %
# Confusion Matrix:
# [[208   0   0]
#  [  7   0   0]
#  [ 27   0   0]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Random Forest - No Vitals Taken (Selected Columns)

# %%
# Data preprocessing
# Drop rows with missing values
df_english.dropna(inplace=True)

# Specify columns for model training
selected_columns = ['Group', 'Age', 'Patients number per hour','Sex', 'Arrival mode', 'Injury', 'Chief_complain', 'Mental', 'Pain', 'Length of stay_min', 'Disposition', 'NRS_pain']

# Separate features and target variable
X = df_english[selected_columns]
y = df_english['mistriage']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Normalize/Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model training with probability estimates
rf_model_selected = RandomForestClassifier(n_estimators=100, random_state=42)

# Perform k-fold cross-validation
cv_scores = cross_val_score(rf_model_selected, X_train, y_train, cv=5)

# Binarize the output for all features
y_test_bin_selected = label_binarize(y_test, classes=[0, 1, 2])


print("Cross-validation scores:", cv_scores)
print("Average cross-validation score:", round(cv_scores.mean() * 100, 2), "%")
# Out:
# Cross-validation scores: [0.88601036 0.86010363 0.86010363 0.86528497 0.87046632]
# Average cross-validation score: 86.84 %

# %%
# Model evaluation
rf_model_selected.fit(X_train, y_train)
y_pred = rf_model_selected.predict(X_test)
y_probs_selected_features = rf_model_selected.predict_proba(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", round(accuracy * 100, 2), "%")

report = classification_report(y_test, y_pred, output_dict=True)
precision = report['macro avg']['precision']
f1_score = report['macro avg']['f1-score']
sensitivity = report['macro avg']['recall']
specificity = report['weighted avg']['recall']

print("Precision:", round(precision * 100, 2), "%")
print("F1 Score:", round(f1_score * 100, 2), "%")
print("Sensitivity:", round(sensitivity * 100, 2), "%")
print("Specificity:", round(specificity * 100, 2), "%")

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 88.84 %
# Precision: 62.84 %
# F1 Score: 45.03 %
# Sensitivity: 41.98 %
# Specificity: 88.84 %
# Confusion Matrix:
# [[208   0   0]
#  [  7   0   0]
#  [ 20   0   7]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # ROC Curves for Random Forest Models

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Plot ROC curve for all features
fpr_all, tpr_all, _ = roc_curve(y_test_bin_all[:, 0], y_probs_all_features[:, 0])
roc_auc_all = roc_auc_score(y_test_bin_all[:, 0], y_probs_all_features[:, 0])
plt.plot(fpr_all, tpr_all, color='blue', lw=2, label=f'All Features (AUC = {roc_auc_all:0.2f})')

# Plot ROC curve for selected features
fpr_sel, tpr_sel, _ = roc_curve(y_test_bin_selected[:, 0], y_probs_selected_features[:, 0])
roc_auc_sel = roc_auc_score(y_test_bin_selected[:, 0], y_probs_selected_features[:, 0])
plt.plot(fpr_sel, tpr_sel, color='red', lw=2, label=f'Selected Features (AUC = {roc_auc_sel:0.2f})')

# Plot the diagonal line (random classifier)
plt.plot([0, 1], [0, 1], 'k--', lw=2)

# Set labels and title
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison \n Between All Features and Selected Columns Random Forest Models')
plt.legend(loc='lower right')
plt.grid(False)

# Show plot
plt.show()

# %% [markdown]
# # Logistic Regression - Vitals Taken (All Features)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Data preprocessing (double check)
df_english.dropna(inplace=True)

# Selecting only the desired features
selected_features = ['Group', 'Age', 'Patients number per hour', 'Sex', 'Arrival mode', 'Injury', 'Chief_complain', 'Mental', 'Pain', 'NRS_pain',
                     'SBP', 'DBP', 'HR', 'RR', 'BT', 'Saturation', 'Length of stay_min', 'Disposition']
X = df_english[selected_features]
y = df_english['mistriage']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Normalize/Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model training with probability estimates
logistic_model_all = LogisticRegression()

# Perform k-fold cross-validation
cv_scores = cross_val_score(logistic_model_all, X_train, y_train, cv=5)

# Binarize the output for all features
y_test_bin_all = label_binarize(y_test, classes=[0, 1, 2])

print("Cross-validation scores:", cv_scores)
print("Average cross-validation score:", round(cv_scores.mean() * 100, 2), "%")
# Out:
# Cross-validation scores: [0.80310881 0.80829016 0.79274611 0.83419689 0.79792746]
# Average cross-validation score: 80.73 %

# %%
# Model evaluation
logistic_model_all.fit(X_train, y_train)
y_pred = logistic_model_all.predict(X_test)
y_probs_all_features = logistic_model_all.predict_proba(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", round(accuracy * 100, 2), "%")

report = classification_report(y_test, y_pred, output_dict=True)
precision = report['macro avg']['precision']
f1_score = report['macro avg']['f1-score']
sensitivity = report['macro avg']['recall']
specificity = report['weighted avg']['recall']

print("Precision:", round(precision * 100, 2), "%")
print("F1 Score:", round(f1_score * 100, 2), "%")
print("Sensitivity:", round(sensitivity * 100, 2), "%")
print("Specificity:", round(specificity * 100, 2), "%")


# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 80.99 %
# Precision: 39.32 %
# F1 Score: 38.38 %
# Sensitivity: 37.86 %
# Specificity: 80.99 %
# Confusion Matrix:
# [[190   5  13]
#  [  6   0   1]
#  [ 20   1   6]]
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Logistic Regression - No Vitals Taken (Selected Columns)

# %%
# Data preprocessing
# Drop rows with missing values
df_english.dropna(inplace=True)

# Specify columns for model training
selected_columns = ['Group', 'Age', 'Patients number per hour','Sex', 'Arrival mode', 'Injury', 'Chief_complain', 'Mental', 'Pain', 'Length of stay_min', 'Disposition', 'NRS_pain']

# Separate features and target variable
X = df_english[selected_columns]
y = df_english['mistriage']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Normalize/Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model training with probability estimates
logistic_model_selected = LogisticRegression(max_iter=1000)

# Perform k-fold cross-validation
cv_scores = cross_val_score(logistic_model_selected, X_train, y_train, cv=5)

# Binarize the output for all features
y_test_bin_selected = label_binarize(y_test, classes=[0, 1, 2])


print("Cross-validation scores:", cv_scores)
print("Average cross-validation score:", round(cv_scores.mean() * 100, 2), "%")
# Out:
# Cross-validation scores: [0.8134715  0.83937824 0.82901554 0.84455959 0.79274611]
# Average cross-validation score: 82.38 %

# %%
# Model evaluation
logistic_model_selected.fit(X_train, y_train)
y_pred = logistic_model_selected.predict(X_test)
y_probs_selected_features = logistic_model_selected.predict_proba(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", round(accuracy * 100, 2), "%")

report = classification_report(y_test, y_pred, output_dict=True)
precision = report['macro avg']['precision']
f1_score = report['macro avg']['f1-score']
sensitivity = report['macro avg']['recall']
specificity = report['weighted avg']['recall']

print("Precision:", round(precision * 100, 2), "%")
print("F1 Score:", round(f1_score * 100, 2), "%")
print("Sensitivity:", round(sensitivity * 100, 2), "%")
print("Specificity:", round(specificity * 100, 2), "%")

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 84.3 %
# Precision: 42.8 %
# F1 Score: 40.08 %
# Sensitivity: 39.14 %
# Specificity: 84.3 %
# Confusion Matrix:
# [[198   3   7]
#  [  5   0   2]
#  [ 21   0   6]]

# %% [markdown]
# # ROC Curves for Logistic Regression Models

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Plot ROC curve for all features
fpr_all, tpr_all, _ = roc_curve(y_test_bin_all[:, 0], y_probs_all_features[:, 0])
roc_auc_all = roc_auc_score(y_test_bin_all[:, 0], y_probs_all_features[:, 0])
plt.plot(fpr_all, tpr_all, color='blue', lw=2, label=f'All Features (AUC = {roc_auc_all:0.2f})')

# Plot ROC curve for selected features
fpr_sel, tpr_sel, _ = roc_curve(y_test_bin_selected[:, 0], y_probs_selected_features[:, 0])
roc_auc_sel = roc_auc_score(y_test_bin_selected[:, 0], y_probs_selected_features[:, 0])
plt.plot(fpr_sel, tpr_sel, color='red', lw=2, label=f'Selected Features (AUC = {roc_auc_sel:0.2f})')

# Plot the diagonal line (random classifier)
plt.plot([0, 1], [0, 1], 'k--', lw=2)

# Set labels and title
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison \n Between All Features and Selected Columns Logistic Regression Models')
plt.legend(loc='lower right')
plt.grid(False)

# Show plot
plt.show()

# %% [markdown]
# # k Nearest Neighbors - Vitals Taken (All Features)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Data preprocessing (double check)
df_english.dropna(inplace=True)

# Selecting only the desired features
selected_features = ['Group', 'Age', 'Patients number per hour', 'Sex', 'Arrival mode', 'Injury', 'Chief_complain', 'Mental', 'Pain', 'NRS_pain',
                     'SBP', 'DBP', 'HR', 'RR', 'BT', 'Saturation', 'Length of stay_min', 'Disposition']
X = df_english[selected_features]
y = df_english['mistriage']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Normalize/Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model training
knn_model_all = KNeighborsClassifier(n_neighbors=5)

# Perform k-fold cross-validation
cv_scores = cross_val_score(knn_model_all, X_train, y_train, cv=5)

# Binarize the output for all features
y_test_bin_all = label_binarize(y_test, classes=[0, 1, 2])

print("Cross-validation scores:", cv_scores)
print("Average cross-validation score:", round(cv_scores.mean() * 100, 2), "%")
# Out:
# Cross-validation scores: [0.85492228 0.85492228 0.84974093 0.85492228 0.84455959]
# Average cross-validation score: 85.18 %

# %%
# Model evaluation
knn_model_all.fit(X_train, y_train)
y_pred = knn_model_all.predict(X_test)
y_probs_all_features = knn_model_all.predict_proba(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", round(accuracy * 100, 2), "%")

report = classification_report(y_test, y_pred, output_dict=True)
precision = report['macro avg']['precision']
f1_score = report['macro avg']['f1-score']
sensitivity = report['macro avg']['recall']
specificity = report['weighted avg']['recall']

print("Precision:", round(precision * 100, 2), "%")
print("F1 Score:", round(f1_score * 100, 2), "%")
print("Sensitivity:", round(sensitivity * 100, 2), "%")
print("Specificity:", round(specificity * 100, 2), "%")


# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 85.95 %
# Precision: 28.65 %
# F1 Score: 30.81 %
# Sensitivity: 33.33 %
# Specificity: 85.95 %
# Confusion Matrix:
# [[208   0   0]
#  [  7   0   0]
#  [ 27   0   0]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # k Nearest Neighbors - No Vitals Taken (Selected Columns)

# %%
# Data preprocessing
# Drop rows with missing values
df_english.dropna(inplace=True)

# Specify columns for model training
selected_columns = ['Group', 'Age', 'Patients number per hour','Sex', 'Arrival mode', 'Injury', 'Chief_complain', 'Mental', 'Pain', 'Length of stay_min', 'Disposition', 'NRS_pain']

# Separate features and target variable
X = df_english[selected_columns]
y = df_english['mistriage']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Normalize/Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model training
knn_model_selected = KNeighborsClassifier(n_neighbors=5)

# Perform k-fold cross-validation
cv_scores = cross_val_score(knn_model_selected, X_train, y_train, cv=5)

# Binarize the output for all features
y_test_bin_selected = label_binarize(y_test, classes=[0, 1, 2])


print("Cross-validation scores:", cv_scores)
print("Average cross-validation score:", round(cv_scores.mean() * 100, 2), "%")
# Out:
# Cross-validation scores: [0.86010363 0.86010363 0.84974093 0.86010363 0.86528497]
# Average cross-validation score: 85.91 %

# %%
# Model evaluation
knn_model_selected.fit(X_train, y_train)
y_pred = knn_model_selected.predict(X_test)
y_probs_all_features = knn_model_selected.predict_proba(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", round(accuracy * 100, 2), "%")

report = classification_report(y_test, y_pred, output_dict=True)
precision = report['macro avg']['precision']
f1_score = report['macro avg']['f1-score']
sensitivity = report['macro avg']['recall']
specificity = report['weighted avg']['recall']

print("Precision:", round(precision * 100, 2), "%")
print("F1 Score:", round(f1_score * 100, 2), "%")
print("Sensitivity:", round(sensitivity * 100, 2), "%")
print("Specificity:", round(specificity * 100, 2), "%")


# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 85.95 %
# Precision: 28.65 %
# F1 Score: 30.81 %
# Sensitivity: 33.33 %
# Specificity: 85.95 %
# Confusion Matrix:
# [[208   0   0]
#  [  7   0   0]
#  [ 27   0   0]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # ROC Curves for k Nearest Neighbor Models

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Plot ROC curve for all features
fpr_all, tpr_all, _ = roc_curve(y_test_bin_all[:, 0], y_probs_all_features[:, 0])
roc_auc_all = roc_auc_score(y_test_bin_all[:, 0], y_probs_all_features[:, 0])
plt.plot(fpr_all, tpr_all, color='blue', lw=2, label=f'All Features (AUC = {roc_auc_all:0.2f})')

# Plot ROC curve for selected features
fpr_sel, tpr_sel, _ = roc_curve(y_test_bin_selected[:, 0], y_probs_selected_features[:, 0])
roc_auc_sel = roc_auc_score(y_test_bin_selected[:, 0], y_probs_selected_features[:, 0])
plt.plot(fpr_sel, tpr_sel, color='red', lw=2, label=f'Selected Features (AUC = {roc_auc_sel:0.2f})')

# Plot the diagonal line (random classifier)
plt.plot([0, 1], [0, 1], 'k--', lw=2)

# Set labels and title
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison \n Between All Features and Selected Columns kNN Models')
plt.legend(loc='lower right')
plt.grid(False)

# Show plot
plt.show()
